# %% [markdown]
# # Math Question Answer Verification Competition
#
# ## Starter Code

# %% [markdown]
# Borrowed from [official Unsloth implementation](https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=MKX_XKs_BNZR)

# %%
# %%capture
# This cell will take time
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth
#   Downloading unsloth-2024.11.7-py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 3.4 MB/s eta 0:00:00
# Collecting unsloth-zoo>=2024.11.1 (from unsloth)
#   Downloading unsloth_zoo-2024.11.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (2.5.1+cu121)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth) (24.2)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.46.2)
# Collecting datasets>=2.16.0 (from unsloth)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.1.1)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.12.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.13.2)
# Collecting protobuf<4.0.0 (from unsloth)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.26.2)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (0.20.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)
# Downloading unsloth-2024.11.7-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 8.3 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 26.0 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.5 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 4.5 MB/s eta 0:00:00
# Downloading trl-0.12.1-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 13.4 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.11.5-py3-none-any.whl (31 kB)
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 78.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.7 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 85.6 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 9.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.0 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, triton, shtab, protobuf, hf-transfer, fsspec, dill, multiprocess, xformers, tyro, bitsandbytes, datasets, trl, unsloth-zoo, unsloth
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 hf-transfer-0.1.8 multiprocess-0.70.16 protobuf-3.20.3 shtab-1.7.1 triton-3.1.0 trl-0.12.1 tyro-0.8.14 unsloth-2024.11.7 unsloth-zoo-2024.11.5 xformers-0.0.28.post3 xxhash-3.5.0
# Found existing installation: unsloth 2024.11.7
# Uninstalling unsloth-2024.11.7:
#   Successfully uninstalled unsloth-2024.11.7
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-r4w47som/unsloth_7ed3c30920094e0597464efdad55d9ea
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-r4w47som/unsloth_7ed3c30920094e0597464efdad55d9ea
#   Resolved https://github.com/unslothai/unsloth.git to commit f26d4e739ed507de7a9088da53d10fd02f58d160
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo>=2024.11.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.14)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.46.2)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.26.2)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.1.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.12.1)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.11.7-py3-none-any.whl size=163138 sha256=c103719445284a2abb0e2187272e403702e73ed74fe826e5d4e275e3139bc17c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_1m6q8tj/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.11.7

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# ## Load model and wrap with LoRA adapters

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,
    lora_dropout = 0,
    bias = "none",
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2024.11.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ## Competition dataset

# %%
from datasets import load_dataset
dataset = load_dataset("ad6398/nyu-dl-teach-maths-comp")
dataset
# Out:
# README.md:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 1000000
#     })
#     test: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 10000
#     })
# })

# %%
prompt = """You are a great mathematician and you are tasked with finding if an answer to a given maths question is correct or not. Yout response should be 'True' if correct, otherwise 'False'. Below is Question and Answer.



### Question:
{}

### Answer:
{}

### Output:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompts_func(examples):
    question = examples["question"]
    ans       = examples["answer"]
    output      = examples["is_correct"]
    texts = []
    for instruction, input, output in zip(question, ans, output):
        text = prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_dataset = dataset['train'].select(range(100000)).map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/100000 [00:00<?, ? examples/s]

# %%
train_dataset['text'][0]
# Out:
# "You are a great mathematician and you are tasked with finding if an answer to a given maths question is correct or not. Yout response should be 'True' if correct, otherwise 'False'. Below is Question and Answer.\n\n\n\n### Question:\nWhat is the radius of the circle inscribed in triangle $ABC$ if $AB = 22, AC=12,$ and $BC=14$? Express your answer in simplest radical form.\n\n### Answer:\n3.16227766016838\n\n### Explainaition\n\n### Output:\nTrue<|end_of_text|>"

# %% [markdown]
# ## SFT

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

training_args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 1000,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    )

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 4,
    packing = False,
    args = training_args
)
# Out:
# Map (num_proc=4):   0%|          | 0/100000 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 100,000 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 1,000
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 1:38:23, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.082300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.647800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.326900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.846900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.869500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.445400</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.254100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.086300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.811300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.901200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.825200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.925700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.894900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.667500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.737800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.794600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.716100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.692600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.708500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.804500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.856400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.682500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.656700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.742300</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.910500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.773200</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.806400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.758200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.730100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.816600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.548900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.821500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.622800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.721000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.774500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.804400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.744400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.842500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.845300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.810300</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.986000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.759400</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.920400</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.817700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.709500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.733700</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.541300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.797200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.716800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.650700</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.808800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.728100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.752800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.863800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.574600</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.690500</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.709000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.845300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.682900</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.735400</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.759500</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.607700</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.835900</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.544800</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.916900</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.832100</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.727900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.844200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.851000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.687200</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.876200</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.642900</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.884600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.702800</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.717800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.736700</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.692100</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.813800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.893200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.842700</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.661500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.570300</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.894400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.862300</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.721800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.828000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.724600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.688100</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.701300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.629200</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.790500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.791200</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.857800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.965900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.787100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.800400</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.754200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.678000</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.603900</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.736500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.846300</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.546300</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.652000</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.687800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.824000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.203200</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.576100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.755600</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.757800</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.757100</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.805500</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.735500</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.722800</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.797900</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.504600</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.831200</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.727700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.897900</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.641700</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.683600</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.709600</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.634000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.845400</td>
#     </tr>
#     <tr>
#       <td>

# %% [markdown]
# ## inference

# %%
test_dataset = dataset['test']

sample_ques = test_dataset['question'][0]
sample_ans = test_dataset['answer'][0]

# %%
import pandas as pd
import torch

FastLanguageModel.for_inference(model)

ids = list(range(len(test_dataset)))
is_correct = []

batch_size = 16
num_batches = (len(test_dataset) + batch_size - 1) // batch_size

for batch_num in range(num_batches):
    print(f"Processing batch {batch_num+1}/{num_batches}")
    start_idx = batch_num * batch_size
    end_idx = min(start_idx + batch_size, len(test_dataset))

    input_prompts = [
        prompt.format(
            test_dataset['question'][i],
            test_dataset['answer'][i],
            ""
        )
        for i in range(start_idx, end_idx)
    ]

    inputs = tokenizer(input_prompts, return_tensors="pt", padding=True).to("cuda")
    input_token_lens = inputs['input_ids'].shape[1]

    outputs = model.generate(**inputs, max_new_tokens=64, use_cache=True)

    responses = tokenizer.batch_decode(outputs[:, input_token_lens:], skip_special_tokens=True)

    for response in responses:
        if response.strip() == 'True' or response.startswith('T'):
            is_correct.append(True)
        else:
            is_correct.append(False)

    del inputs
    del outputs
    torch.cuda.empty_cache()

data = {'ID': ids, 'is_correct': is_correct}
df = pd.DataFrame(data)
df.to_csv('optimized_inference.csv', index=False, header=True)
# Out:
# Processing batch 1/625
# Processing batch 2/625
# Processing batch 3/625
# Processing batch 4/625
# Processing batch 5/625
# Processing batch 6/625
# Processing batch 7/625
# Processing batch 8/625
# Processing batch 9/625
# Processing batch 10/625
# Processing batch 11/625
# Processing batch 12/625
# Processing batch 13/625
# Processing batch 14/625
# Processing batch 15/625
# Processing batch 16/625
# Processing batch 17/625
# Processing batch 18/625
# Processing batch 19/625
# Processing batch 20/625
# Processing batch 21/625
# Processing batch 22/625
# Processing batch 23/625
# Processing batch 24/625
# Processing batch 25/625
# Processing batch 26/625
# Processing batch 27/625
# Processing batch 28/625
# Processing batch 29/625
# Processing batch 30/625
# Processing batch 31/625
# Processing batch 32/625
# Processing batch 33/625
# Processing batch 34/625
# Processing batch 35/625
# Processing batch 36/625
# Processing batch 37/625
# Processing batch 38/625
# Processing batch 39/625
# Processing batch 40/625
# Processing batch 41/625
# Processing batch 42/625
# Processing batch 43/625
# Processing batch 44/625
# Processing batch 45/625
# Processing batch 46/625
# Processing batch 47/625
# Processing batch 48/625
# Processing batch 49/625
# Processing batch 50/625
# Processing batch 51/625
# Processing batch 52/625
# Processing batch 53/625
# Processing batch 54/625
# Processing batch 55/625
# Processing batch 56/625
# Processing batch 57/625
# Processing batch 58/625
# Processing batch 59/625
# Processing batch 60/625
# Processing batch 61/625
# Processing batch 62/625
# Processing batch 63/625
# Processing batch 64/625
# Processing batch 65/625
# Processing batch 66/625
# Processing batch 67/625
# Processing batch 68/625
# Processing batch 69/625
# Processing batch 70/625
# Processing batch 71/625
# Processing batch 72/625
# Processing batch 73/625
# Processing batch 74/625
# Processing batch 75/625
# Processing batch 76/625
# Processing batch 77/625
# Processing batch 78/625
# Processing batch 79/625
# Processing batch 80/625
# Processing batch 81/625
# Processing batch 82/625
# Processing batch 83/625
# Processing batch 84/625
# Processing batch 85/625
# Processing batch 86/625
# Processing batch 87/625
# Processing batch 88/625
# Processing batch 89/625
# Processing batch 90/625
# Processing batch 91/625
# Processing batch 92/625
# Processing batch 93/625
# Processing batch 94/625
# Processing batch 95/625
# Processing batch 96/625
# Processing batch 97/625
# Processing batch 98/625
# Processing batch 99/625
# Processing batch 100/625
# Processing batch 101/625
# Processing batch 102/625
# Processing batch 103/625
# Processing batch 104/625
# Processing batch 105/625
# Processing batch 106/625
# Processing batch 107/625
# Processing batch 108/625
# Processing batch 109/625
# Processing batch 110/625
# Processing batch 111/625
# Processing batch 112/625
# Processing batch 113/625
# Processing batch 114/625
# Processing batch 115/625
# Processing batch 116/625
# Processing batch 117/625
# Processing batch 118/625
# Processing batch 119/625
# Processing batch 120/625
# Processing batch 121/625
# Processing batch 122/625
# Processing batch 123/625
# Processing batch 124/625
# Processing batch 125/625
# Processing batch 126/625
# Processing batch 127/625
# Processing batch 128/625
# Processing batch 129/625
# Processing batch 130/625
# Processing batch 131/625
# Processing batch 132/625
# Processing batch 133/625
# Processing batch 134/625
# Processing batch 135/625
# Processing batch 136/625
# Processing batch 137/625
# Processing batch 138/625
# Processing batch 139/625
# Processing batch 140/625
# Processing batch 141/625
# Processing batch 142/625
# Processing batch 143/625
# Processing batch 144/625
# Processing batch 145/625
# Processing batch 146/625
# Processing batch 147/625
# Processing batch 148/625
# Processing batch 149/625
# Processing batch 150/625
# Processing batch 151/625
# Processing batch 152/625
# Processing batch 153/625
# Processing batch 154/625
# Processing batch 155/625
# Processing batch 156/625
# Processing batch 157/625
# Processing batch 158/625
# Processing batch 159/625
# Processing batch 160/625
# Processing batch 161/625
# Processing batch 162/625
# Processing batch 163/625
# Processing batch 164/625
# Processing batch 165/625
# Processing batch 166/625
# Processing batch 167/625
# Processing batch 168/625
# Processing batch 169/625
# Processing batch 170/625
# Processing batch 171/625
# Processing batch 172/625
# Processing batch 173/625
# Processing batch 174/625
# Processing batch 175/625
# Processing batch 176/625
# Processing batch 177/625
# Processing batch 178/625
# Processing batch 179/625
# Processing batch 180/625
# Processing batch 181/625
# Processing batch 182/625
# Processing batch 183/625
# Processing batch 184/625
# Processing batch 185/625
# Processing batch 186/625
# Processing batch 187/625
# Processing batch 188/625
# Processing batch 189/625
# Processing batch 190/625
# Processing batch 191/625
# Processing batch 192/625
# Processing batch 193/625
# Processing batch 194/625
# Processing batch 195/625
# Processing batch 196/625
# Processing batch 197/625
# Processing batch 198/625
# Processing batch 199/625
# Processing batch 200/625
# Processing batch 201/625
# Processing batch 202/625
# Processing batch 203/625
# Processing batch 204/625
# Processing batch 205/625
# Processing batch 206/625
# Processing batch 207/625
# Processing batch 208/625
# Processing batch 209/625
# Processing batch 210/625
# Processing batch 211/625
# Processing batch 212/625
# Processing batch 213/625
# Processing batch 214/625
# Processing batch 215/625
# Processing batch 216/625
# Processing batch 217/625
# Processing batch 218/625
# Processing batch 219/625
# Processing batch 220/625
# Processing batch 221/625
# Processing batch 222/625
# Processing batch 223/625
# Processing batch 224/625
# Processing batch 225/625
# Processing batch 226/625
# Processing batch 227/625
# Processing batch 228/625
# Processing batch 229/625
# Processing batch 230/625
# Processing batch 231/625
# Processing batch 232/625
# Processing batch 233/625
# Processing batch 234/625
# Processing batch 235/625
# Processing batch 236/625
# Processing batch 237/625
# Processing batch 238/625
# Processing batch 239/625
# Processing batch 240/625
# Processing batch 241/625
# Processing batch 242/625
# Processing batch 243/625
# Processing batch 244/625
# Processing batch 245/625
# Processing batch 246/625
# Processing batch 247/625
# Processing batch 248/625
# Processing batch 249/625
# Processing batch 250/625
# Processing batch 251/625
# Processing batch 252/625
# Processing batch 253/625
# Processing batch 254/625
# Processing batch 255/625
# Processing batch 256/625
# Processing batch 257/625
# Processing batch 258/625
# Processing batch 259/625
# Processing batch 260/625
# Processing batch 261/625
# Processing batch 262/625
# Processing batch 263/625
# Processing batch 264/625
# Processing batch 265/625
# Processing batch 266/625
# Processing batch 267/625
# Processing batch 268/625
# Processing batch 269/625
# Processing batch 270/625
# Processing batch 271/625
# Processing batch 272/625
# Processing batch 273/625
# Processing batch 274/625
# Processing batch 275/625
# Processing batch 276/625
# Processing batch 277/625
# Processing batch 278/625
# Processing batch 279/625
# Processing batch 280/625
# Processing batch 281/625
# Processing batch 282/625
# Processing batch 283/625
# Processing batch 284/625
# Processing batch 285/625
# Processing batch 286/625
# Processing batch 287/625
# Processing batch 288/625
# Processing batch 289/625
# Processing batch 290/625
# Processing batch 291/625
# Processing batch 292/625
# Processing batch 293/625
# Processing batch 294/625
# Processing batch 295/625
# Processing batch 296/625
# Processing batch 297/625
# Processing batch 298/625
# Processing batch 299/625
# Processing batch 300/625
# Processing batch 301/625
# Processing batch 302/625
# Processing batch 303/625
# Processing batch 304/625
# Processing batch 305/625
# Processing batch 306/625
# Processing batch 307/625
# Processing batch 308/625
# Processing batch 309/625
# Processing batch 310/625
# Processing batch 311/625
# Processing batch 312/625
# Processing batch 313/625
# Processing batch 314/625
# Processing batch 315/625
# Processing batch 316/625
# Processing batch 317/625
# Processing batch 318/625
# Processing batch 319/625
# Processing batch 320/625
# Processing batch 321/625
# Processing batch 322/625
# Processing batch 323/625
# Processing batch 324/625
# Processing batch 325/625
# Processing batch 326/625
# Processing batch 327/625
# Processing batch 328/625
# Processing batch 329/625
# Processing batch 330/625
# Processing batch 331/625
# Processing batch 332/625
# Processing batch 333/625
# Processing batch 334/625
# Processing batch 335/625
# Processing batch 336/625
# Processing batch 337/625
# Processing batch 338/625
# Processing batch 339/625
# Processing batch 340/625
# Processing batch 341/625
# Processing batch 342/625
# Processing batch 343/625
# Processing batch 344/625
# Processing batch 345/625
# Processing batch 346/625
# Processing batch 347/625
# Processing batch 348/625
# Processing batch 349/625
# Processing batch 350/625
# Processing batch 351/625
# Processing batch 352/625
# Processing batch 353/625
# Processing batch 354/625
# Processing batch 355/625
# Processing batch 356/625
# Processing batch 357/625
# Processing batch 358/625
# Processing batch 359/625
# Processing batch 360/625
# Processing batch 361/625
# Processing batch 362/625
# Processing batch 363/625
# Processing batch 364/625
# Processing batch 365/625
# Processing batch 366/625
# Processing batch 367/625
# Processing batch 368/625
# Processing batch 369/625
# Processing batch 370/625
# Processing batch 371/625
# Processing batch 372/625
# Processing batch 373/625
# Processing batch 374/625
# Processing batch 375/625
# Processing batch 376/625
# Processing batch 377/625
# Processing batch 378/625
# Processing batch 379/625
# Processing batch 380/625
# Processing batch 381/625
# Processing batch 382/625
# Processing batch 383/625
# Processing batch 384/625
# Processing batch 385/625
# Processing batch 386/625
# Processing batch 387/625
# Processing batch 388/625
# Processing batch 389/625
# Processing batch 390/625
# Processing batch 391/625
# Processing batch 392/625
# Processing batch 393/625
# Processing batch 394/625
# Processing batch 395/625
# Processing batch 396/625
# Processing batch 397/625
# Processing batch 398/625
# Processing batch 399/625
# Processing batch 400/625
# Processing batch 401/625
# Processing batch 402/625
# Processing batch 403/625
# Processing batch 404/625
# Processing batch 405/625
# Processing batch 406/625
# Processing batch 407/625
# Processing batch 408/625
# Processing batch 409/625
# Processing batch 410/625
# Processing batch 411/625
# Processing batch 412/625
# Processing batch 413/625
# Processing batch 414/625
# Processing batch 415/625
# Processing batch 416/625
# Processing batch 417/625
# Processing batch 418/625
# Processing batch 419/625
# Processing batch 420/625
# Processing batch 421/625
# Processing batch 422/625
# Processing batch 423/625
# Processing batch 424/625
# Processing batch 425/625
# Processing batch 426/625
# Processing batch 427/625
# Processing batch 428/625
# Processing batch 429/625
# Processing batch 430/625
# Processing batch 431/625
# Processing batch 432/625
# Processing batch 433/625
# Processing batch 434/625
# Processing batch 435/625
# Processing batch 436/625
# Processing batch 437/625
# Processing batch 438/625
# Processing batch 439/625
# Processing batch 440/625
# Processing batch 441/625
# Processing batch 442/625
# Processing batch 443/625
# Processing batch 444/625
# Processing batch 445/625
# Processing batch 446/625
# Processing batch 447/625
# Processing batch 448/625
# Processing batch 449/625
# Processing batch 450/625
# Processing batch 451/625
# Processing batch 452/625
# Processing batch 453/625
# Processing batch 454/625
# Processing batch 455/625
# Processing batch 456/625
# Processing batch 457/625
# Processing batch 458/625
# Processing batch 459/625
# Processing batch 460/625
# Processing batch 461/625
# Processing batch 462/625
# Processing batch 463/625
# Processing batch 464/625
# Processing batch 465/625
# Processing batch 466/625
# Processing batch 467/625
# Processing batch 468/625
# Processing batch 469/625
# Processing batch 470/625
# Processing batch 471/625
# Processing batch 472/625
# Processing batch 473/625
# Processing batch 474/625
# Processing batch 475/625
# Processing batch 476/625
# Processing batch 477/625
# Processing batch 478/625
# Processing batch 479/625
# Processing batch 480/625
# Processing batch 481/625
# Processing batch 482/625
# Processing batch 483/625
# Processing batch 484/625
# Processing batch 485/625
# Processing batch 486/625
# Processing batch 487/625
# Processing batch 488/625
# Processing batch 489/625
# Processing batch 490/625
# Processing batch 491/625
# Processing batch 492/625
# Processing batch 493/625
# Processing batch 494/625
# Processing batch 495/625
# Processing batch 496/625
# Processing batch 497/625
# Processing batch 498/625
# Processing batch 499/625
# Processing batch 500/625
# Processing batch 501/625
# Processing batch 502/625
# Processing batch 503/625
# Processing batch 504/625
# Processing batch 505/625
# Processing batch 506/625
# Processing batch 507/625
# Processing batch 508/625
# Processing batch 509/625
# Processing batch 510/625
# Processing batch 511/625
# Processing batch 512/625
# Processing batch 513/625
# Processing batch 514/625
# Processing batch 515/625
# Processing batch 516/625
# Processing batch 517/625
# Processing batch 518/625
# Processing batch 519/625
# Processing batch 520/625
# Processing batch 521/625
# Processing batch 522/625
# Processing batch 523/625
# Processing batch 524/625
# Processing batch 525/625
# Processing batch 526/625
# Processing batch 527/625
# Processing batch 528/625
# Processing batch 529/625
# Processing batch 530/625
# Processing batch 531/625
# Processing batch 532/625
# Processing batch 533/625
# Processing batch 534/625
# Processing batch 535/625
# Processing batch 536/625
# Processing batch 537/625
# Processing batch 538/625
# Processing batch 539/625
# Processing batch 540/625
# Processing batch 541/625
# Processing batch 542/625
# Processing batch 543/625
# Processing batch 544/625
# Processing batch 545/625
# Processing batch 546/625
# Processing batch 547/625
# Processing batch 548/625
# Processing batch 549/625
# Processing batch 550/625
# Processing batch 551/625
# Processing batch 552/625
# Processing batch 553/625
# Processing batch 554/625
# Processing batch 555/625
# Processing batch 556/625
# Processing batch 557/625
# Processing batch 558/625
# Processing batch 559/625
# Processing batch 560/625
# Processing batch 561/625
# Processing batch 562/625
# Processing batch 563/625
# Processing batch 564/625
# Processing batch 565/625
# Processing batch 566/625
# Processing batch 567/625
# Processing batch 568/625
# Processing batch 569/625
# Processing batch 570/625
# Processing batch 571/625
# Processing batch 572/625
# Processing batch 573/625
# Processing batch 574/625
# Processing batch 575/625
# Processing batch 576/625
# Processing batch 577/625
# Processing batch 578/625
# Processing batch 579/625
# Processing batch 580/625
# Processing batch 581/625
# Processing batch 582/625
# Processing batch 583/625
# Processing batch 584/625
# Processing batch 585/625
# Processing batch 586/625
# Processing batch 587/625
# Processing batch 588/625
# Processing batch 589/625
# Processing batch 590/625
# Processing batch 591/625
# Processing batch 592/625
# Processing batch 593/625
# Processing batch 594/625
# Processing batch 595/625
# Processing batch 596/625
# Processing batch 597/625
# Processing batch 598/625
# Processing batch 599/625
# Processing batch 600/625
# Processing batch 601/625
# Processing batch 602/625
# Processing batch 603/625
# Processing batch 604/625
# Processing batch 605/625
# Processing batch 606/625
# Processing batch 607/625
# Processing batch 608/625
# Processing batch 609/625
# Processing batch 610/625
# Processing batch 611/625
# Processing batch 612/625
# Processing batch 613/625
# Processing batch 614/625
# Processing batch 615/625
# Processing batch 616/625
# Processing batch 617/625
# Processing batch 618/625
# Processing batch 619/625
# Processing batch 620/625
# Processing batch 621/625
# Processing batch 622/625
# Processing batch 623/625
# Processing batch 624/625
# Processing batch 625/625

# %% [markdown]
# ## saving model

# %%
model.save_pretrained("lora_model")
tokenizer.save_pretrained("lora_model")
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model",
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 7.5. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
